# %%
# Dependencies
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import math
import seaborn as sns
from scipy.stats import kendalltau
sns.set(style="ticks")
import reverse_geocoder as rg
from scipy.stats import ttest_ind

# %%
# The path to our CSV file
rig_file = "rig_count_output.csv"

# Read our rig count data into pandas
rig_df = pd.read_csv(rig_file)

rig_df.head()
# Out:
#           Unix  Alabama  Alaska  Arizona  Arkansas  California  Colorado  \
# 0  946684800.0     1.50    4.50      0.0      0.25       16.50     18.25
# 1  949363200.0     0.25    4.75      0.0      0.00       16.75     17.25
# 2  951868800.0     0.80    5.80      0.0      0.00       18.00     17.60
# 3  954547200.0     1.50    4.50      0.0      2.25       18.25     18.25
# 4  957139200.0     2.00    5.25      0.0      6.00       20.25     17.00
#
#    D.C.  Delaware  Florida  ...   Tennesee   Texas   Utah  Vermont  Virginia  \
# 0   0.0       0.0      0.0  ...        0.0  268.75  14.00      0.0      0.25
# 1   0.0       0.0      0.0  ...        0.0  277.25  14.00      0.0      0.25
# 2   0.0       0.0      0.0  ...        0.0  273.20  15.60      0.0      1.20
# 3   0.0       0.0      0.0  ...        0.0  285.00  14.50      0.0      2.00
# 4   0.0       0.0      0.0  ...        0.0  295.00  15.75      0.0      2.75
#
#    W. Virgina  Wash.  Wisconsin  Wyoming  Time
# 0        9.75    0.0        0.0    38.75   1.0
# 1        5.00    0.0        0.0    34.00   2.0
# 2        5.80    0.0        0.0    30.20   3.0
# 3       10.00    0.0        0.0    28.25   4.0
# 4       11.25    0.0        0.0    29.75   5.0
#
# [5 rows x 54 columns]

# %%
# The path to our CSV file
seismic_file = "seismic_data_9-28-17.csv"

# Read our rig count data into pandas
seismic_df = pd.read_csv(seismic_file)

seismic_df.columns
# Out:
# Index(['Unnamed: 0', 'alert', 'cd_by_month', 'cd_by_year', 'cd_for_plot',
#        'cdi', 'code', 'converted_date', 'coordinates_3', 'detail', 'dmin',
#        'epoch_by_month', 'felt', 'gap', 'geo_type', 'ids', 'lat', 'lng', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
reverse_geo = seismic_df
reverse_geo.head()
# Out:
#    Unnamed: 0 alert cd_by_month  cd_by_year              cd_for_plot  cdi  \
# 0           0   NaN     04-1906        1906  1906-04-18 13:12:27.000  NaN
# 1           1   NaN     04-1906        1906  1915-10-03 06:53:21.000  NaN
# 2           2   NaN     10-1915        1915  1918-07-15 00:23:13.000  NaN
# 3           3   NaN     07-1918        1918  1918-05-23 11:57:40.000  NaN
# 4           4   NaN     05-1918        1918  1918-04-21 22:32:29.000  NaN
#
#        code converted_date  coordinates_3  \
# 0  16957905     04-18-1906           10.0
# 1    913944     04-18-1906           10.0
# 2    913200     10-03-1915           15.0
# 3    913151     07-15-1918           10.0
# 4    913126     05-23-1918           10.0
#
#                                               detail  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#                          ...                                        sources  \
# 0                        ...                                       ,iscgem,
# 1                        ...                                       ,iscgem,
# 2                        ...                          ,iscgem,is,iscgemsup,
# 3                        ...                          ,is,iscgem,iscgemsup,
# 4                        ...                                       ,iscgem,
#
#       status           time                                 title tsunami  \
# 0  automatic -2010394053000     M 7.7 - San Pablo Bay, California       0
# 1  automatic -1711904799000                        M 6.8 - Nevada       0
# 2  automatic -1624145807000  M 6.4 - offshore Northern California       0
# 3  automatic -1628683340000                M 6.8 - Sonora, Mexico       0
# 4  automatic -1631410051000           M 6.7 - Southern California       0
#
#          type     types  tz        updated  \
# 0  earthquake  ,origin, NaN  1431543161000
# 1  earthquake  ,origin, NaN  1431543161000
# 2  earthquake  ,origin, NaN  1436806942000
# 3  earthquake  ,origin, NaN  1436806942000
# 4  earthquake  ,origin, NaN  1431543161000
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 36 columns]

# %%
# Create a state column for the reverse_geo
reverse_geo['State'] = ''
reverse_geo.columns
# Out:
# Index(['Unnamed: 0', 'alert', 'cd_by_month', 'cd_by_year', 'cd_for_plot',
#        'cdi', 'code', 'converted_date', 'coordinates_3', 'detail', 'dmin',
#        'epoch_by_month', 'felt', 'gap', 'geo_type', 'ids', 'lat', 'lng', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'State'],
#       dtype='object')

# %%
#counter = 0
result = []

# Populate the DF
#for index, row in reverse_geo.iterrows():
  #  try:
        # Counter keeps track of where we are in record retrieval process
       #counter += 1
       
     #   coordinates = (row['lat'], row['lng'])
        #print(coordinates)
        
       # result = rg.search(coordinates) # default mode = 2
       # print(result)
        #state = result['admin1']
        #print(result.get('admin1'))
      #  reverse_geo.set_value(index, "State", result.get([3]['admin1']))
      #  break
        
        
                                      
                                      
       
  #  except:
    #    print('error.')
       
        
        
reverse_geo.head()
# Out:
#    Unnamed: 0 alert cd_by_month  cd_by_year              cd_for_plot  cdi  \
# 0           0   NaN     04-1906        1906  1906-04-18 13:12:27.000  NaN
# 1           1   NaN     04-1906        1906  1915-10-03 06:53:21.000  NaN
# 2           2   NaN     10-1915        1915  1918-07-15 00:23:13.000  NaN
# 3           3   NaN     07-1918        1918  1918-05-23 11:57:40.000  NaN
# 4           4   NaN     05-1918        1918  1918-04-21 22:32:29.000  NaN
#
#        code converted_date  coordinates_3  \
# 0  16957905     04-18-1906           10.0
# 1    913944     04-18-1906           10.0
# 2    913200     10-03-1915           15.0
# 3    913151     07-15-1918           10.0
# 4    913126     05-23-1918           10.0
#
#                                               detail  ...      status  \
# 0  https://earthquake.usgs.gov/fdsnws/event/1/que...  ...   automatic
# 1  https://earthquake.usgs.gov/fdsnws/event/1/que...  ...   automatic
# 2  https://earthquake.usgs.gov/fdsnws/event/1/que...  ...   automatic
# 3  https://earthquake.usgs.gov/fdsnws/event/1/que...  ...   automatic
# 4  https://earthquake.usgs.gov/fdsnws/event/1/que...  ...   automatic
#
#             time                                 title  tsunami        type  \
# 0 -2010394053000     M 7.7 - San Pablo Bay, California        0  earthquake
# 1 -1711904799000                        M 6.8 - Nevada        0  earthquake
# 2 -1624145807000  M 6.4 - offshore Northern California        0  earthquake
# 3 -1628683340000                M 6.8 - Sonora, Mexico        0  earthquake
# 4 -1631410051000           M 6.7 - Southern California        0  earthquake
#
#       types  tz        updated  \
# 0  ,origin, NaN  1431543161000
# 1  ,origin, NaN  1431543161000
# 2  ,origin, NaN  1436806942000
# 3  ,origin, NaN  1436806942000
# 4  ,origin, NaN  1431543161000
#
#                                                  url State
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 37 columns]

# %%
seismic_df.rename(columns={'epoch_by_month': 'Unix'}, inplace=True)
seismic_df.columns
# Out:
# Index(['Unnamed: 0', 'alert', 'cd_by_month', 'cd_by_year', 'cd_for_plot',
#        'cdi', 'code', 'converted_date', 'coordinates_3', 'detail', 'dmin',
#        'Unix', 'felt', 'gap', 'geo_type', 'ids', 'lat', 'lng', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url', 'State'],
#       dtype='object')

# %%
seismic_df = seismic_df.pivot_table(index = 'Unix', aggfunc = np.mean)
seismic_df
# Out:
#              Unnamed: 0  cd_by_year       cdi  coordinates_3      dmin  \
# Unix
# -2011910400         0.5      1906.0       NaN      10.000000       NaN
# -1712102400         2.0      1915.0       NaN      15.000000       NaN
# -1633219200         5.0      1918.0  6.400000      10.000000       NaN
# -1630627200         4.0      1918.0       NaN      10.000000       NaN
# -1625356800         3.0      1918.0       NaN      10.000000       NaN
# -1509667200        10.0      1922.0       NaN      10.000000       NaN
# -1464912000         9.0      1923.0       NaN      10.000000       NaN
# -1414972800         8.0      1925.0       NaN      10.000000       NaN
# -1407024000         6.5      1925.0       NaN      15.000000       NaN
# -1364947200        13.0      1926.0       NaN       6.000000  1.202000
# -1330732800        12.0      1927.0       NaN      10.000000       NaN
# -1414972800  0.000000         NaN  1.431543e+12
# -1407024000  0.000000         NaN  1.431543e+12
# -1364947200  0.000000         NaN  1.453921e+12
# -1330732800  0.000000         NaN  1.431543e+12
# -1299110400  0.000000         NaN  1.431543e+12
# -1230768000  0.000000         NaN  1.453944e+12
# -1212451200  0.000000         NaN  1.431543e+12
# -1199232000  0.000000         NaN  1.456250e+12
# -1196553600  0.000000         NaN  1.456758e+12
# -1194048000  0.000000         NaN  1.453920e+12
# -1191369600  0.000000         NaN  1.453920e+12
# -1188777600  0.000000         NaN  1.453920e+12
# -1186099200  0.000000         NaN  1.452725e+12
# -1183507200  0.000000         NaN  1.451974e+12
# -1180828800  0.000000         NaN  1.454176e+12
# -1178150400  0.000000         NaN  1.453920e+12
# -1175558400  0.000000         NaN  1.453920e+12
# -1172880000  0.000000         NaN  1.453920e+12
# -1170288000  0.000000         NaN  1.452988e+12
# -1167609600  0.000000         NaN  1.453920e+12
# -1164931200  0.000000         NaN  1.453920e+12
# -1162512000  0.000000         NaN  1.454102e+12
# -1159833600  0.000000         NaN  1.454123e+12
# ...               ...         ...           ...
#  1427846400  0.000000 -330.000000  1.443454e+12
#  1430438400  0.005305 -340.612813  1.446889e+12
#  1433116800  0.000000 -327.718310  1.446141e+12
#  1435708800  0.005236 -340.054496  1.450806e+12
#  1438387200  0.000000 -335.471698  1.452747e+12
#  1441065600  0.004843 -338.636364  1.455139e+12
#  1443657600  0.000000 -338.595506  1.458440e+12
#  1446336000  0.000000 -386.756757  1.458958e+12
#  1448928000  0.005222 -404.150943  1.460710e+12
#  1451606400  0.006881 -390.213777  1.462445e+12
#  1454284800  0.004854 -392.506329  1.465323e+12
#  1456790400  0.003311 -368.478261  1.467278e+12
#  1459468800  0.000000 -342.587413  1.469618e+12
#  1462060800  0.003676 -335.813953  1.471399e+12
#  1464739200  0.003759 -343.095238  1.473235e+12
#  1467331200  0.006993 -338.059701  1.475727e+12
#  1470009600  0.004219 -355.446429  1.480207e+12
#  1472688000  0.002597 -339.622642  1.481138e+12
#  1475280000  0.000000 -347.272727  1.484599e+12
#  1477958400  0.004000 -391.673820  1.486832e+12
#  1480550400  0.009901 -425.052632  1.489293e+12
#  1483228800  0.000000 -418.571429  1.490509e+12
#  1485907200  0.006098 -410.704225  1.493664e+12
#  1488326400  0.003846 -410.987124  1.495728e+12
#  1491004800  0.000000 -412.390244  1.498010e+12
#  1493596800  0.004762 -401.347150  1.500916e+12
#  1496275200  0.004274 -408.750000  1.502775e+12
#  1498867200  0.000000 -420.217391  1.502123e+12
#  1501545600  0.000000 -415.731225  1.504414e+12
#  1504224000  0.000000 -420.524476  1.505729e+12
#
# [1043 rows x 18 columns]

# %%
counter = 0

seismic_df['Time'] = ''
#rig_count_df['Unix'] = ''
# Populate the DF
for index, row in seismic_df.iterrows():
    try:
        # Counter keeps track of where we are in record retrieval process
       counter += 1
       seismic_df.set_value(index, "Time", counter)
        
        
        
                                      
                                      
       
    except:
       print('error.')
       
        
        
seismic_df.head()
# Out:
#              Unnamed: 0  cd_by_year  cdi  coordinates_3  dmin  felt  gap  \
# Unix
# -2011910400         0.5      1906.0  NaN           10.0   NaN   NaN  NaN
# -1712102400         2.0      1915.0  NaN           15.0   NaN   NaN  NaN
# -1633219200         5.0      1918.0  6.4           10.0   NaN  77.0  NaN
# -1630627200         4.0      1918.0  NaN           10.0   NaN   NaN  NaN
# -1625356800         3.0      1918.0  NaN           10.0   NaN   NaN  NaN
#
#                 lat       lng   mag  mmi  nst  rms    sig          time  \
# Unix
# -2011910400  39.157 -120.0285  7.25  NaN  NaN  NaN  811.5 -1.861149e+12
# -1712102400  41.304 -124.6940  6.40  NaN  NaN  NaN  630.0 -1.624146e+12
# -1633219200  34.300 -119.8000  6.82  NaN  NaN  NaN  765.0 -1.404552e+12
# -1630627200  33.647 -117.4330  6.70  NaN  NaN  NaN  691.0 -1.631410e+12
# -1625356800  27.102 -110.1220  6.80  NaN  NaN  NaN  711.0 -1.628683e+12
#
#              tsunami     tz       updated Time
# Unix
# -2011910400      0.0    NaN  1.431543e+12    1
# -1712102400      0.0    NaN  1.436807e+12    2
# -1633219200      0.0 -480.0  1.498272e+12    3
# -1630627200      0.0    NaN  1.431543e+12    4
# -1625356800      0.0    NaN  1.436807e+12    5

# %%
combined_df = pd.merge(seismic_df, rig_df, how='inner', right_index = False, left_index=False)
combined_df.dtypes

#rig_df.join(seismic_df)
#rig_df.columns
# Out:
# Unnamed: 0       float64
# cd_by_year       float64
# cdi              float64
# coordinates_3    float64
# dmin             float64
# felt             float64
# gap              float64
# lat              float64
# lng              float64
# mag              float64
# mmi              float64
# nst              float64
# rms              float64
# sig              float64
# time             float64
# tsunami          float64
# tz               float64
# updated          float64
# Time              object
# Unix             float64
# Alabama          float64
# Alaska           float64
# Arizona          float64
# Arkansas         float64
# California       float64
# Colorado         float64
# D.C.             float64
# Delaware         float64
# Florida          float64
# Georgia          float64
#                   ...
# Minn.            float64
# Mississippi      float64
# Missouri         float64
# Montana          float64
# N. Carolina      float64
# N. Dakota        float64
# N. Hamp.         float64
# N. Jersey        float64
# N. Mexico        float64
# N. York          float64
# Nebraska         float64
# Nevada           float64
# Ohio             float64
# Oklahoma         float64
# Oregon           float64
# Penn.            float64
# Rhode Is.        float64
# S. Carolina      float64
# S. Dakota        float64
# TOTAL            float64
# TOTAL US         float64
# Tennesee         float64
# Texas            float64
# Utah             float64
# Vermont          float64
# Virginia         float64
# W. Virgina       float64
# Wash.            float64
# Wisconsin        float64
# Wyoming          float64
# Length: 72, dtype: object

# %%
# Take a look at it in CSV
#combined_df.to_csv("combined_inner_data.csv")

# %%
x = (combined_df["Time"])

y1 = combined_df["mag"]
y2 = combined_df["TOTAL US"]


fig, ax1 = plt.subplots()
ax2 = ax1.twinx()
ax1.scatter(x, y1, c='r')
ax2.scatter(x, y2, c='b')


ax1.set_ylim(2.5, 4)

# Incorporate the other graph properties
plt.title("Earthquake Magnitude and Rig Count by Month/ Year")# + " " + year_range)
ax1.set_ylabel("Average Magnitude Earthquakes", color = "r")
ax2.set_ylabel("Average Rig Count", color = "b")
plt.xlabel("Years")
plt.grid(True)

# Save the figure
#plt.savefig("Magnitude and Count by Year.png")


# formatter = 
# plt.gcf().axes[0].xaxis.set_major_formatter(formatter)

plt.show()

# %%
# Plot the Data
plt.scatter(np.arange(0, len(combined_df)), combined_df['mag'], c="r", alpha=0.09, label="Earthquakes")
plt.scatter(np.arange(0, len(combined_df)), combined_df['Texas'],  c="b", label="Rigs")
plt.legend(loc="best")
plt.xlabel("Rigs")
plt.ylabel("Earthquakes")
plt.title("Something")
#plt.show()

# %%
# Draw a KDE chart in Seaborn
sns.jointplot(x = combined_df['Time'], y = combined_df['mag'], size = 10, #data = combined_df['TOTAL US'], 
              kind="kde", stat_func=ttest_ind, color="#4CB391")

#plt.xlim(0, 225)
plt.ylim(2.5, 4)
plt.show()

# %%
# Draw a KDE chart in Seaborn
sns.jointplot(x = combined_df['Time'], y = combined_df['TOTAL US'], size = 10, #data = combined_df['TOTAL US'], 
              kind="kde", stat_func=kendalltau, color="#4CB391")

#plt.xlim(0, 225)
#plt.ylim(2.5, 4)
plt.show()

# %%
# Draw a KDE chart in Seaborn
sns.jointplot(x = combined_df['TOTAL US'], y = combined_df['mag'], size = 10 # data = rig_count_df
              , kind="kde", stat_func=ttest_ind, color="#4CB391")

#plt.xlim(0, 225)
plt.ylim(2.5, 4)
plt.show()

# %%
# Run 1-Sample T-Test
stats.ttest_1samp(a=combined_df['TOTAL US'], popmean=combined_df['mag'].mean())
# Out:
# Ttest_1sampResult(statistic=40.830960906784554, pvalue=2.0666059892906391e-102)

# %%
# Run 2-Sample T-Test
stats.ttest_ind(combined_df['TOTAL US'], combined_df['mag'], equal_var=False)
# Out:
# Ttest_indResult(statistic=40.830893758516027, pvalue=2.0653741008818769e-102)

# %%
# Run 2-Sample T-Test
stats.ttest_ind(combined_df['Oklahoma'], combined_df['mag'], equal_var=False)
# Out:
# Ttest_indResult(statistic=47.231640684210177, pvalue=1.5217210507975217e-114)

# %%
# Run 2-Sample T-Test
stats.ttest_ind(combined_df['Texas'], combined_df['mag'], equal_var=True)
# Out:
# Ttest_indResult(statistic=37.984138664118433, pvalue=1.4884511636458836e-138)

# %%
# Run 2-Sample T-Test
#stats.ttest_ind(seismic_df['mag'], rig_df['Texas'], equal_var=False)

# %%
# Run Chi-Square Test to determine goodness of fit
#stats.chisquare(f_obs=sorority_counts, f_exp=sorority_expected)

# %%
# Chi-squared with contingency
#stats.chi2_contingency(observed= observed)

# %%
# Perform the ANOVA
#stats.f_oneway(asian, black, hispanic, other, white)
