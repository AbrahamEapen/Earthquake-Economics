# %%
# Dependencies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# The path to our CSV file
file = "rig_count_updated.csv"

# Read our rig count data into pandas
df = pd.read_csv(file)


df.head()
# Out:
#                        DATE  Unix Date  Alabama  Alaska  Arizona  Arkansas  \
# 0   Friday, January 7, 2000  947203200        2       3        0         1
# 1  Friday, January 14, 2000  947808000        2       6        0         0
# 2  Friday, January 21, 2000  948412800        1       5        0         0
# 3  Friday, January 28, 2000  949017600        1       4        0         0
# 4  Friday, February 4, 2000  949622400        0       4        0         0
#
#    California  Colorado  Delaware  D.C.     ...       Texas  Utah  Vermont  \
# 0          16        19         0     0     ...         271    15        0
# 1          16        18         0     0     ...         268    14        0
# 2          17        19         0     0     ...         273    14        0
# 3          17        17         0     0     ...         263    13        0
# 4          15        18         0     0     ...         272    14        0
#
# ...

# %%
# Place bins into categories
#quarter = pd.cut(seismic_data['time'], bins, labels = group_names)
df['quarter'] = pd.cut(df['Unix Date'], bins, labels = group_names)
#np.nan_to_num(seismic_data)
df
# Out:
#                            DATE   Unix Date  Alabama  Alaska  Arizona  \
# 0       Friday, January 7, 2000   947203200        2       3        0
# 1      Friday, January 14, 2000   947808000        2       6        0
# 2      Friday, January 21, 2000   948412800        1       5        0
# 3      Friday, January 28, 2000   949017600        1       4        0
# 4      Friday, February 4, 2000   949622400        0       4        0
# 5     Friday, February 11, 2000   950227200        0       5        0
# 6     Friday, February 18, 2000   950832000        0       5        0
# 7     Friday, February 25, 2000   951436800        1       5        0
# 8         Friday, March 3, 2000   952041600        2       7        0
# 9        Friday, March 10, 2000   952646400        2       7        0
# 10       Friday, March 17, 2000   953251200        0       5        0
# 11       Friday, March 24, 2000   953856000        0       5        0
# ...

# %%
# Try to make a first chart
df.groupby(by = ['quarter'])['TOTAL US'].sum
#df.columns = df.columns.astype(str).str.strip()
#df.columns = df.columns.str.strip()
#print (df.columns.tolist())
#['quarter', 'TOTAL US']
plt.scatter(x = 'quarter', y = 'TOTAL US', data = df, )#size = 6, aspect = 2 )
plt.show()

# %%
# Try to make a first chart
sns.lmplot(x = 'Unix Date', y = 'Oklahoma', data = df, size = 6, aspect = 2 )
plt.show()

# %%
# Try to make a first chart
sns.lmplot(x = 'Unix Date', y = 'W. Virgina', data = df, size = 6, aspect = 2 )
plt.show()
