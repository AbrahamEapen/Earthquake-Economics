# %%
## Seismic Analysis Impact on NR&C - T-Test
## By: Fervis Lauan
## Date: 09-29-17
##----------------------------------------------------

import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import math

file1 = './Resources/seismic_test_emp_pop_ttest.csv'
seis_test_pop = pd.read_csv(file1)
seis_test_pop
# Out:
#     Unnamed: 0    Zip  Emp Const Extr Change
# 0            0  96130               0.094763
# 1            1  89406               0.105940
# 2            2  95501              -0.138624
# 3            3  93117               0.186652
# 4            4  82520               0.057646
# 5            5  73013              -0.029612
# 6            6  95422               0.039134
# 7            7  73020               0.078351
# 8            8  95540               0.021088
# 9            9  75964              -0.126543
# 10          10  93555              -0.013992
# 11          11  93561              -0.067995
# 12          12  92284              -0.108707
# 13          13  75652              -0.074454
# 14          14  89433               0.085335
# 15          15  93212               0.066921
# 16          16  90275               0.138024
# 17          17  93436               0.045355
# 18          18  96150               0.006821

# %%
file2 = './Resources/seismic_ctrl_emp_pop_ttest.csv'
seis_ctrl_pop = pd.read_csv(file2)
seis_ctrl_pop
# Out:
#      Unnamed: 0    Zip  Emp Const Extr Change
# 0         27400  78744               0.005919
# 1          6476  21012              -0.020608
# 2         15819  48141               0.358491
# 3          7123  23224               0.056384
# 4         27793  80002              -0.180728
# 5         12194  37760              -0.065856
# 6         11515  35761              -0.016765
# 7         16164  48854              -0.006387
# 8         20869  61080              -0.013393
# 9         16418  49418              -0.130435
# 10        24406  70815              -0.078708
# 11        14245  44134               0.026976
# 12         7914  25504               0.068602
# 13         7572  24541              -0.106796
# 14        16436  49445               0.085620
# 15         2889  11411              -0.172000
# 16        11516  35763               0.086134
# 17         4777  15801              -0.241319
# 18        15256  46802               0.050682
# ...

# %%
seis_test_pop["Emp Const Extr Change"].mean()
# Out:
# 0.01926859492127512

# %%
seis_ctrl_pop["Emp Const Extr Change"].mean()
# Out:
# 0.010064514751711886

# %%
stats.ttest_1samp(a=seis_test_pop["Emp Const Extr Change"], popmean=seis_ctrl_pop["Emp Const Extr Change"].mean())
# Out:
# Ttest_1sampResult(statistic=0.43857323055923036, pvalue=0.66618938399991601)
